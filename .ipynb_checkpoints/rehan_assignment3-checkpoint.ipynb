# %%
#Question_NO.1 Program to print the string in a specified format
print("Twinkle, twinkle, little star,")
print("\tHow I wonder what you are!")
print("\t\tUp above the world so high,")
print("\t\tLike a diamond in the sky.")
print("Twinkle, twinkle, little star,")
print("\tHow I wonder what you are")



#Question_NO.2 Program to get python version
import sys
print("Python version you are using")
print (sys.version)
print("Version information")
print (sys.version_info)


#Question_NO.3 Program to display current time
import datetime
date_time = datetime.datetime.now()
print ("Current Date & Time")
print (date_time.strftime("%Y-%m-%d %H:%M:%S"))


#Question_NO.4 Program to compute the area of circle
print("Enter radius of circle:")
r=int(input())
area=3.14*r*r
print("Area of Circle:",area)


#Question_NO.5 Program which take name as input and display in reverse order with space between
print("Enter first name:")
fname=input()
print("Enter last name:")
lname=input()
print("Reversed Name:",lname," ",fname)


#Question_NO.6 Program which print the addition of numbers
x=int(input("Enter first value:"))
y=int(input("Enter second value:"))
print(x,"+",y,"=",x+y)


#Question_NO.7 Program to compute marksheet
mathematics=int(input("Enter marks of Mathematics"))
islamiyat=int(input("Enter marks of Islamiyat"))
english=int(input("Enter marks of English"))
computer=int(input("Enter marks of Computer"))
physics=int(input("Enter marks of Physics"))
total=500
percentage=((mathematics+islamiyat+english+physics+computer)/total)*100
if percentage>100 or percentage<0:
    print("Invalid Percentage")
elif percentage>=90 and percentage<=100:
    print("A+")
elif percentage>=80 and percentage<90:
    print("A")
elif percentage >= 70 and percentage < 80:
    print("B")
elif percentage>=60 and percentage<70:
    print("C")
elif percentage>=50 and percentage<60:
    print("D")
else:
    print("F")



#Question_NO.8 Program to identify the given number is even or odd 
num=int(input("Enter a number:"))
if num%2==0:
    print(num," is even")
else:
    print(num," is odd")



#Question_NO.9 Program to print the length of list
myList=["ali","ahmad",2,"rehan",4,"mariam"]
print("List items are: ",myList)
print("Lenght of List ", len(myList))


#Question_NO.10 Program to print the sum of all numeric items in a list
myList=[1,2,3,4,5]
print("List Numbers are:",myList)
sum=0
for i in myList:
    sum=sum+i
print("Sum is:",sum)



#Question_NO.11 Program to print the largest number from a numeric list
myList=[11,2,21,22,21,6,7,10]
print("List items are: ",myList)
max=myList[0]
for i in myList:
    if i>=max:
        max=i
print("Largest number is ",max)



#Question_NO.12 Program to print all the elements of a list that are less than 5
myList=[0,1,3,4,5,6,9,10,13]
print("Elements less than 5")
for i in myList:
    if i<5:
        print(i)
